# %% [markdown]
# # Classification Binaire de Tumeurs Cérébrales par IRM
#
# **Équipe :** Redouane Hamecha · Malick Diatara · Yazid Aloui · Omar El Medjoubi · Mohamed Achoch · N'Guessan Yves Guichard Allou
#
# ---
#
# Ce notebook présente une version finale, réorganisée et commentée du projet.

# %% [markdown]
# ## 1. Imports et configuration

# %%
# -----------------------------
# Bibliothèques standards
# -----------------------------
import os
import random
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# -----------------------------
# PyTorch
# -----------------------------
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import models
from torchvision.models import EfficientNet_B0_Weights, ResNet18_Weights

# -----------------------------
# Augmentations et métriques
# -----------------------------
import albumentations as A
from albumentations.pytorch import ToTensorV2
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
)

from tqdm.auto import tqdm

# -----------------------------
# Reproductibilité
# On fixe une seed pour limiter
# la variabilité entre exécutions
# -----------------------------
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# -----------------------------
# Choix automatique du device
# -----------------------------
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["font.size"] = 11

print("Seed :", SEED)
print("Device :", DEVICE)
if DEVICE.type == "cuda":
    print("GPU :", torch.cuda.get_device_name(0))
# Out:
# Seed : 42
# Device : cuda
# GPU : Tesla T4

# %% [markdown]
# ## 2. Compréhension du problème

# %%
import kagglehub

# Téléchargement du dataset depuis KaggleHub
dataset_path = Path(kagglehub.dataset_download("sartajbhuvaji/brain-tumor-classification-mri"))
TRAIN_DIR = dataset_path / "Training"
TEST_DIR = dataset_path / "Testing"

IMG_EXTS = {".jpg", ".jpeg", ".png"}

def count_images(folder):
    # Cette fonction compte le nombre d'images dans chaque sous-dossier
    counts = {}
    for cls_dir in sorted(Path(folder).iterdir()):
        if cls_dir.is_dir():
            n = len([f for f in cls_dir.iterdir() if f.suffix.lower() in IMG_EXTS])
            counts[cls_dir.name] = n
    return counts

train_counts = count_images(TRAIN_DIR)
test_counts = count_images(TEST_DIR)

print("TRAIN_DIR :", TRAIN_DIR)
print("TEST_DIR  :", TEST_DIR)
print("Training :", train_counts)
print("Testing  :", test_counts)
print("Total train :", sum(train_counts.values()))
print("Total test  :", sum(test_counts.values()))
# Out:
# TRAIN_DIR : /kaggle/input/datasets/sartajbhuvaji/brain-tumor-classification-mri/Training
# TEST_DIR  : /kaggle/input/datasets/sartajbhuvaji/brain-tumor-classification-mri/Testing
# Training : {'glioma_tumor': 826, 'meningioma_tumor': 822, 'no_tumor': 395, 'pituitary_tumor': 827}
# Testing  : {'glioma_tumor': 100, 'meningioma_tumor': 115, 'no_tumor': 105, 'pituitary_tumor': 74}
# Total train : 2870
# Total test  : 394

# %% [markdown]
# ## 3. Analyse exploratoire

# %%
# Pour la version binaire :
# - no_tumor devient la classe saine
# - les trois autres classes sont regroupées dans la classe tumeur
tumor_count = sum(v for k, v in train_counts.items() if k != "no_tumor")
healthy_count = train_counts["no_tumor"]

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

bars = axes[0].bar(
    list(train_counts.keys()),
    list(train_counts.values()),
    color=["#d9e8f5", "#b8d3ea", "#8fbce6", "#5c9ed6"]
)
axes[0].set_title("Distribution des classes originales")
axes[0].set_ylabel("Nombre d'images")
axes[0].tick_params(axis="x", rotation=20)

# Ajout des valeurs sur les barres pour faciliter la lecture
for bar in bars:
    h = bar.get_height()
    axes[0].text(bar.get_x() + bar.get_width()/2, h + 10, f"{int(h)}", ha="center", fontsize=9)

bars = axes[1].bar(
    ["Pas de tumeur", "Tumeur"],
    [healthy_count, tumor_count],
    color=["#d9e8f5", "#5c9ed6"]
)
axes[1].set_title("Distribution binaire")
axes[1].set_ylabel("Nombre d'images")

for bar in bars:
    h = bar.get_height()
    axes[1].text(bar.get_x() + bar.get_width()/2, h + 10, f"{int(h)}", ha="center", fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusion – Analyse exploratoire
#
# - Le dataset est fortement déséquilibré
# - Environ 86 % des images contiennent une tumeur contre 14 % sans tumeur
# - Ce déséquilibre justifie l'utilisation du recall et du F1-score
# - Les dimensions varient, ce qui impose un redimensionnement à 224 × 224

# %%
# Affichage de quelques exemples visuels par classe
fig, axes = plt.subplots(2, 4, figsize=(14, 7))
classes = sorted(train_counts.keys())

for j, cls_name in enumerate(classes):
    cls_dir = TRAIN_DIR / cls_name
    images = sorted([f for f in cls_dir.iterdir() if f.suffix.lower() in IMG_EXTS])[:2]
    for i, img_path in enumerate(images):
        img = Image.open(img_path).convert("RGB")
        axes[i, j].imshow(img)
        axes[i, j].set_title(cls_name)
        axes[i, j].axis("off")

plt.tight_layout()
plt.show()

# %%
# Vérification des dimensions des images
# Cela permet de confirmer le besoin d'un Resize uniforme
widths, heights = [], []

for cls_dir in TRAIN_DIR.iterdir():
    if not cls_dir.is_dir():
        continue
    for img_path in list(cls_dir.iterdir())[:100]:
        if img_path.suffix.lower() in IMG_EXTS:
            img = Image.open(img_path)
            widths.append(img.size[0])
            heights.append(img.size[1])

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].hist(widths, bins=20, color="#d9e8f5", edgecolor="white")
axes[0].axvline(224, color="black", linestyle="--")
axes[0].set_title("Distribution des largeurs")

axes[1].hist(heights, bins=20, color="#8fbce6", edgecolor="white")
axes[1].axvline(224, color="black", linestyle="--")
axes[1].set_title("Distribution des hauteurs")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Préparation des données

# %%
class BrainMRIDataset(Dataset):
    """Dataset binaire : 0 = sain, 1 = tumeur."""

    def __init__(self, root_dir, transform=None):
        self.root_dir = Path(root_dir)
        self.transform = transform
        self.samples = []

        # Construction de la liste des échantillons
        # Chaque élément = (chemin_image, label_binaire)
        for cls_dir in sorted(self.root_dir.iterdir()):
            if not cls_dir.is_dir():
                continue

            label = 0 if cls_dir.name == "no_tumor" else 1

            for img_path in sorted(cls_dir.iterdir()):
                if img_path.suffix.lower() in IMG_EXTS:
                    self.samples.append((img_path, label))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]

        # Lecture image
        image = np.array(Image.open(img_path).convert("RGB"))

        # Application des transformations si définies
        if self.transform is not None:
            image = self.transform(image=image)["image"]

        label = torch.tensor(label, dtype=torch.long)
        return image, label


# Normalisation ImageNet :
# elle est utilisée pour rester cohérent avec les modèles pré-entraînés
IMAGENET_MEAN = (0.485, 0.456, 0.406)
IMAGENET_STD = (0.229, 0.224, 0.225)
IMG_SIZE = 224

def get_train_transforms():
    # Augmentations simples pour l'entraînement de base
    return A.Compose([
        A.Resize(IMG_SIZE, IMG_SIZE),
        A.HorizontalFlip(p=0.5),
        A.Rotate(limit=10, p=0.5),
        A.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD),
        ToTensorV2(),
    ])

def get_train_transforms_advanced():
    # Version plus riche utilisée pour le fine-tuning
    return A.Compose([
        A.Resize(IMG_SIZE, IMG_SIZE),
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.3),
        A.Rotate(limit=12, p=0.5),
        A.RandomBrightnessContrast(brightness_limit=0.10, contrast_limit=0.10, p=0.3),
        A.GaussNoise(p=0.2),
        A.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD),
        ToTensorV2(),
    ])

def get_eval_transforms():
    # Pas d'augmentation en validation / test
    return A.Compose([
        A.Resize(IMG_SIZE, IMG_SIZE),
        A.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD),
        ToTensorV2(),
    ])

def get_tta_transforms():
    # TTA = plusieurs versions légères d'une même image au moment de l'inférence
    return [
        get_eval_transforms(),
        A.Compose([
            A.Resize(IMG_SIZE, IMG_SIZE),
            A.HorizontalFlip(p=1.0),
            A.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD),
            ToTensorV2(),
        ]),
        A.Compose([
            A.Resize(IMG_SIZE, IMG_SIZE),
            A.VerticalFlip(p=1.0),
            A.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD),
            ToTensorV2(),
        ]),
        A.Compose([
            A.Resize(IMG_SIZE, IMG_SIZE),
            A.Rotate(limit=(10, 10), p=1.0),
            A.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD),
            ToTensorV2(),
        ]),
    ]

# %%
# Création du split train / validation avec stratification
# pour conserver la proportion des classes dans les deux ensembles
full_dataset = BrainMRIDataset(TRAIN_DIR, transform=None)
labels_all = [label for _, label in full_dataset.samples]
idx_all = np.arange(len(labels_all))

train_idx, val_idx = train_test_split(
    idx_all,
    test_size=0.2,
    random_state=SEED,
    stratify=labels_all,
)

# On crée des datasets séparés car les transformations
# ne sont pas les mêmes entre train et validation
train_dataset = BrainMRIDataset(TRAIN_DIR, transform=get_train_transforms())
val_dataset = BrainMRIDataset(TRAIN_DIR, transform=get_eval_transforms())
test_dataset = BrainMRIDataset(TEST_DIR, transform=get_eval_transforms())

train_set = Subset(train_dataset, train_idx)
val_set = Subset(val_dataset, val_idx)

BATCH_SIZE = 32

# DataLoaders PyTorch
train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

print("Train :", len(train_set))
print("Validation :", len(val_set))
print("Test :", len(test_dataset))
# Out:
# Train : 2296
# Validation : 574
# Test : 394

# %% [markdown]
# ## 5. Fonctions communes

# %%
def train_one_epoch(model, loader, criterion, optimizer, device):
    """Entraîne le modèle sur une époque complète."""
    model.train()
    running_loss = 0.0
    n_samples = 0
    correct = 0

    for images, labels in tqdm(loader, desc="Train", leave=False):
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)
        n_samples += images.size(0)

        # En classification multi-classe ou binaire à 2 logits,
        # argmax renvoie la classe prédite
        preds = torch.argmax(outputs, dim=1)
        correct += (preds == labels).sum().item()

    return running_loss / n_samples, correct / n_samples


@torch.no_grad()
def validate_one_epoch(model, loader, criterion, device):
    """Évalue le modèle et conserve aussi les probabilités utiles au threshold tuning."""
    model.eval()
    running_loss = 0.0
    n_samples = 0
    correct = 0
    all_targets, all_preds, all_probs = [], [], []

    for images, labels in tqdm(loader, desc="Eval", leave=False):
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * images.size(0)
        n_samples += images.size(0)

        # Softmax transforme les logits en probabilités
        probs = torch.softmax(outputs, dim=1)
        preds = torch.argmax(outputs, dim=1)
        correct += (preds == labels).sum().item()

        all_targets.extend(labels.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())

        # On garde uniquement la probabilité de la classe 1 = tumeur
        all_probs.extend(probs[:, 1].cpu().numpy())

    return {
        "loss": running_loss / n_samples,
        "acc": correct / n_samples,
        "targets": np.array(all_targets),
        "preds": np.array(all_preds),
        "probs": np.array(all_probs),
    }


def compute_metrics(y_true, y_pred):
    """Fonction centralisée pour éviter de recalculer les métriques à plusieurs endroits."""
    return {
        "accuracy": accuracy_score(y_true, y_pred),
        "precision": precision_score(y_true, y_pred, zero_division=0),
        "recall": recall_score(y_true, y_pred, zero_division=0),
        "f1": f1_score(y_true, y_pred, zero_division=0),
        "cm": confusion_matrix(y_true, y_pred),
        "report": classification_report(y_true, y_pred, zero_division=0, digits=4),
    }


@torch.no_grad()
def predict_tta(model, dataset, device, tta_transforms=None):
    """Applique plusieurs transformations de test et moyenne les probabilités obtenues."""
    if tta_transforms is None:
        tta_transforms = get_tta_transforms()

    model.eval()
    all_probs, all_targets = [], []

    for idx in tqdm(range(len(dataset)), desc="TTA", leave=False):
        if hasattr(dataset, "indices"):
            img_path, label = dataset.dataset.samples[dataset.indices[idx]]
        else:
            img_path, label = dataset.samples[idx]

        image_np = np.array(Image.open(img_path).convert("RGB"))
        probs_per_version = []

        for t in tta_transforms:
            img_t = t(image=image_np)["image"].unsqueeze(0).to(device)
            output = model(img_t)
            prob = torch.softmax(output, dim=1)[0, 1].item()
            probs_per_version.append(prob)

        # Moyenne des probabilités sur toutes les versions de l'image
        all_probs.append(np.mean(probs_per_version))
        all_targets.append(label)

    return np.array(all_targets), np.array(all_probs)


def predict_with_threshold(probs, threshold=0.5):
    # Convertit une probabilité en classe binaire selon un seuil choisi
    return np.array([1 if p >= threshold else 0 for p in probs])


def evaluate_thresholds_with_tta(model, dataset, device, thresholds):
    """Recherche du meilleur seuil selon le F1-score."""
    y_true, probs = predict_tta(model, dataset, device)

    rows = []
    for thr in thresholds:
        preds = predict_with_threshold(probs, threshold=float(thr))
        rows.append([
            thr,
            precision_score(y_true, preds, zero_division=0),
            recall_score(y_true, preds, zero_division=0),
            f1_score(y_true, preds, zero_division=0),
        ])

    df = pd.DataFrame(rows, columns=["Seuil", "Precision", "Recall", "F1-score"])
    best_thr = df.loc[df["F1-score"].idxmax(), "Seuil"]
    best_preds = predict_with_threshold(probs, threshold=float(best_thr))
    metrics = compute_metrics(y_true, best_preds)

    return df, best_thr, metrics


def plot_training_curves(history, title_suffix=""):
    # Affiche l'évolution de la loss et de l'accuracy
    epochs = range(1, len(history["train_loss"]) + 1)
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    axes[0].plot(epochs, history["train_loss"], marker="o", label="Train")
    axes[0].plot(epochs, history["val_loss"], marker="o", label="Validation")
    axes[0].set_title(f"Loss {title_suffix}")
    axes[0].legend()

    axes[1].plot(epochs, history["train_acc"], marker="o", label="Train")
    axes[1].plot(epochs, history["val_acc"], marker="o", label="Validation")
    axes[1].set_title(f"Accuracy {title_suffix}")
    axes[1].legend()

    plt.tight_layout()
    plt.show()


def train_model_with_early_stopping(
    model,
    train_loader,
    val_loader,
    criterion_train,
    criterion_eval,
    optimizer,
    device,
    max_epochs=15,
    patience=3,
    checkpoint_path=None,
    label=""
):
    """Boucle d'entraînement générique avec sauvegarde du meilleur modèle."""
    history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}
    best_val_loss = float("inf")
    wait = 0

    for epoch in range(max_epochs):
        train_loss, train_acc = train_one_epoch(model, train_loader, criterion_train, optimizer, device)
        val_result = validate_one_epoch(model, val_loader, criterion_eval, device)

        history["train_loss"].append(train_loss)
        history["val_loss"].append(val_result["loss"])
        history["train_acc"].append(train_acc)
        history["val_acc"].append(val_result["acc"])

        print(
            f"[{label}] Epoch {epoch+1:02d}/{max_epochs} | "
            f"Train loss: {train_loss:.4f} | Train acc: {train_acc:.4f} | "
            f"Val loss: {val_result['loss']:.4f} | Val acc: {val_result['acc']:.4f}"
        )

        # Si la loss de validation s'améliore,
        # on sauvegarde le modèle et on remet le compteur à zéro
        if val_result["loss"] < best_val_loss:
            best_val_loss = val_result["loss"]
            wait = 0
            if checkpoint_path is not None:
                torch.save(model.state_dict(), checkpoint_path)
        else:
            wait += 1
            if wait >= patience:
                print(f"Early stopping déclenché pour {label}.")
                break

    return history

# %% [markdown]
# ## 6. CNN from scratch et améliorations

# %%
class SmallCNN(nn.Module):
    """Petit CNN construit depuis zéro pour servir de baseline."""

    def __init__(self, img_size=224, num_classes=2):
        super().__init__()

        # Partie convolutionnelle :
        # elle apprend progressivement des motifs visuels
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
        )

        flattened_dim = 128 * (img_size // 8) * (img_size // 8)

        # Partie classification :
        # elle transforme les features en décision finale
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(flattened_dim, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(0.3),
            nn.Linear(256, num_classes),
        )

    def forward(self, x):
        return self.classifier(self.features(x))

# %%
save_dir = Path("artifacts/checkpoints")
save_dir.mkdir(parents=True, exist_ok=True)

criterion_eval = nn.CrossEntropyLoss()

# -----------------------------
# CNN standard
# -----------------------------
cnn_model_base = SmallCNN().to(DEVICE)
criterion_std = nn.CrossEntropyLoss()
optimizer_std = torch.optim.Adam(cnn_model_base.parameters(), lr=1e-3)

history_cnn_base = train_model_with_early_stopping(
    model=cnn_model_base,
    train_loader=train_loader,
    val_loader=val_loader,
    criterion_train=criterion_std,
    criterion_eval=criterion_eval,
    optimizer=optimizer_std,
    device=DEVICE,
    max_epochs=15,
    patience=3,
    checkpoint_path=save_dir / "smallcnn_base_best.pt",
    label="CNN standard"
)

cnn_model_base.load_state_dict(torch.load(save_dir / "smallcnn_base_best.pt", map_location=DEVICE))
plot_training_curves(history_cnn_base, "(CNN standard)")

val_result = validate_one_epoch(cnn_model_base, val_loader, criterion_eval, DEVICE)
cnn_base_metrics = compute_metrics(val_result["targets"], val_result["preds"])
# Out:
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN standard] Epoch 01/15 | Train loss: 2.3503 | Train acc: 0.8584 | Val loss: 0.2241 | Val acc: 0.8920
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN standard] Epoch 02/15 | Train loss: 0.2044 | Train acc: 0.9146 | Val loss: 0.1777 | Val acc: 0.9286
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN standard] Epoch 03/15 | Train loss: 0.1794 | Train acc: 0.9186 | Val loss: 0.1830 | Val acc: 0.9199
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN standard] Epoch 04/15 | Train loss: 0.1563 | Train acc: 0.9159 | Val loss: 0.1861 | Val acc: 0.9233
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN standard] Epoch 05/15 | Train loss: 0.1449 | Train acc: 0.9368 | Val loss: 0.1355 | Val acc: 0.9495
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN standard] Epoch 06/15 | Train loss: 0.1368 | Train acc: 0.9416 | Val loss: 0.1881 | Val acc: 0.9408
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN standard] Epoch 07/15 | Train loss: 0.1474 | Train acc: 0.9403 | Val loss: 0.1566 | Val acc: 0.9530
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN standard] Epoch 08/15 | Train loss: 0.1298 | Train acc: 0.9412 | Val loss: 0.1811 | Val acc: 0.9286
# Early stopping déclenché pour CNN standard.
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]

# %%
# -----------------------------
# CNN avec label smoothing
# Le label smoothing évite que le
# modèle devienne trop confiant
# trop tôt pendant l'entraînement
# -----------------------------
cnn_model = SmallCNN().to(DEVICE)
criterion_smooth = nn.CrossEntropyLoss(label_smoothing=0.05)
optimizer = torch.optim.Adam(cnn_model.parameters(), lr=1e-3)

history_cnn = train_model_with_early_stopping(
    model=cnn_model,
    train_loader=train_loader,
    val_loader=val_loader,
    criterion_train=criterion_smooth,
    criterion_eval=criterion_eval,
    optimizer=optimizer,
    device=DEVICE,
    max_epochs=15,
    patience=3,
    checkpoint_path=save_dir / "smallcnn_best.pt",
    label="CNN loss ajustée"
)

cnn_model.load_state_dict(torch.load(save_dir / "smallcnn_best.pt", map_location=DEVICE))
plot_training_curves(history_cnn, "(CNN loss ajustée)")

val_result = validate_one_epoch(cnn_model, val_loader, criterion_eval, DEVICE)
cnn_metrics = compute_metrics(val_result["targets"], val_result["preds"])
# Out:
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN loss ajustée] Epoch 01/15 | Train loss: 3.4978 | Train acc: 0.8484 | Val loss: 0.2348 | Val acc: 0.9077
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN loss ajustée] Epoch 02/15 | Train loss: 0.2919 | Train acc: 0.9186 | Val loss: 0.1911 | Val acc: 0.9111
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN loss ajustée] Epoch 03/15 | Train loss: 0.2585 | Train acc: 0.9325 | Val loss: 0.1788 | Val acc: 0.9233
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN loss ajustée] Epoch 04/15 | Train loss: 0.2508 | Train acc: 0.9347 | Val loss: 0.1765 | Val acc: 0.9146
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN loss ajustée] Epoch 05/15 | Train loss: 0.2514 | Train acc: 0.9242 | Val loss: 0.1873 | Val acc: 0.9024
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN loss ajustée] Epoch 06/15 | Train loss: 0.2434 | Train acc: 0.9382 | Val loss: 0.1817 | Val acc: 0.9129
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN loss ajustée] Epoch 07/15 | Train loss: 0.2417 | Train acc: 0.9334 | Val loss: 0.1520 | Val acc: 0.9251
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN loss ajustée] Epoch 08/15 | Train loss: 0.2196 | Train acc: 0.9421 | Val loss: 0.1631 | Val acc: 0.9443
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN loss ajustée] Epoch 09/15 | Train loss: 0.2163 | Train acc: 0.9486 | Val loss: 0.1320 | Val acc: 0.9443
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN loss ajustée] Epoch 10/15 | Train loss: 0.2081 | Train acc: 0.9486 | Val loss: 0.1445 | Val acc: 0.9338
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN loss ajustée] Epoch 11/15 | Train loss: 0.2119 | Train acc: 0.9438 | Val loss: 0.1205 | Val acc: 0.9495
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN loss ajustée] Epoch 12/15 | Train loss: 0.2004 | Train acc: 0.9564 | Val loss: 0.1699 | Val acc: 0.9547
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN loss ajustée] Epoch 13/15 | Train loss: 0.2035 | Train acc: 0.9530 | Val loss: 0.1412 | Val acc: 0.9425
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN loss ajustée] Epoch 14/15 | Train loss: 0.1908 | Train acc: 0.9656 | Val loss: 0.1487 | Val acc: 0.9373
# Early stopping déclenché pour CNN loss ajustée.
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]

# %%
# -----------------------------
# CNN spécialisé
# Ici on repart du meilleur CNN
# précédent puis on applique des
# augmentations plus avancées
# -----------------------------
train_dataset_adv = BrainMRIDataset(TRAIN_DIR, transform=get_train_transforms_advanced())
train_set_adv = Subset(train_dataset_adv, train_idx)
train_loader_adv = DataLoader(train_set_adv, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)

cnn_model_ft = SmallCNN().to(DEVICE)
cnn_model_ft.load_state_dict(torch.load(save_dir / "smallcnn_best.pt", map_location=DEVICE))
optimizer_cnn_ft = torch.optim.Adam(cnn_model_ft.parameters(), lr=5e-4)

history_cnn_ft = train_model_with_early_stopping(
    model=cnn_model_ft,
    train_loader=train_loader_adv,
    val_loader=val_loader,
    criterion_train=criterion_smooth,
    criterion_eval=criterion_eval,
    optimizer=optimizer_cnn_ft,
    device=DEVICE,
    max_epochs=15,
    patience=3,
    checkpoint_path=save_dir / "smallcnn_ft_best.pt",
    label="CNN spécialisé"
)

cnn_model_ft.load_state_dict(torch.load(save_dir / "smallcnn_ft_best.pt", map_location=DEVICE))
plot_training_curves(history_cnn_ft, "(CNN spécialisé)")

val_result = validate_one_epoch(cnn_model_ft, val_loader, criterion_eval, DEVICE)
cnn_ft_metrics = compute_metrics(val_result["targets"], val_result["preds"])

thresholds = np.arange(0.30, 0.71, 0.05)
cnn_threshold_df, best_threshold_cnn, cnn_tta_metrics = evaluate_thresholds_with_tta(
    cnn_model_ft, val_set, DEVICE, thresholds
)

cnn_progress_df = pd.DataFrame({
    "Version CNN": ["Base", "Loss ajustée", "Spécialisé", "Spécialisé + TTA"],
    "Accuracy": [cnn_base_metrics["accuracy"], cnn_metrics["accuracy"], cnn_ft_metrics["accuracy"], cnn_tta_metrics["accuracy"]],
    "Precision": [cnn_base_metrics["precision"], cnn_metrics["precision"], cnn_ft_metrics["precision"], cnn_tta_metrics["precision"]],
    "Recall": [cnn_base_metrics["recall"], cnn_metrics["recall"], cnn_ft_metrics["recall"], cnn_tta_metrics["recall"]],
    "F1-score": [cnn_base_metrics["f1"], cnn_metrics["f1"], cnn_ft_metrics["f1"], cnn_tta_metrics["f1"]],
})

cnn_progress_df
# Out:
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN spécialisé] Epoch 01/15 | Train loss: 0.3675 | Train acc: 0.8876 | Val loss: 0.2082 | Val acc: 0.9286
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN spécialisé] Epoch 02/15 | Train loss: 0.3168 | Train acc: 0.9107 | Val loss: 0.1822 | Val acc: 0.9268
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN spécialisé] Epoch 03/15 | Train loss: 0.2957 | Train acc: 0.9207 | Val loss: 0.1606 | Val acc: 0.9338
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN spécialisé] Epoch 04/15 | Train loss: 0.2774 | Train acc: 0.9264 | Val loss: 0.1816 | Val acc: 0.9164
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN spécialisé] Epoch 05/15 | Train loss: 0.2786 | Train acc: 0.9251 | Val loss: 0.1737 | Val acc: 0.9251
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN spécialisé] Epoch 06/15 | Train loss: 0.2585 | Train acc: 0.9325 | Val loss: 0.1452 | Val acc: 0.9460
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN spécialisé] Epoch 07/15 | Train loss: 0.2690 | Train acc: 0.9233 | Val loss: 0.1937 | Val acc: 0.9199
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN spécialisé] Epoch 08/15 | Train loss: 0.2533 | Train acc: 0.9307 | Val loss: 0.1489 | Val acc: 0.9408
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [CNN spécialisé] Epoch 09/15 | Train loss: 0.2466 | Train acc: 0.9377 | Val loss: 0.1725 | Val acc: 0.9146
# Early stopping déclenché pour CNN spécialisé.
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# TTA:   0%|          | 0/574 [00:00<?, ?it/s]
#         Version CNN  Accuracy  Precision    Recall  F1-score
# 0              Base  0.949477   0.975510  0.965657  0.970558
# 1      Loss ajustée  0.949477   0.962302  0.979798  0.970971
# 2        Spécialisé  0.945993   0.962151  0.975758  0.968907
# 3  Spécialisé + TTA  0.945993   0.973469  0.963636  0.968528

# %% [markdown]
# ### Conclusion – Modèles CNN
#
# - Le CNN standard atteint déjà de bonnes performances
# - Le label smoothing n'apporte pas d'amélioration nette
# - Le fine-tuning du CNN améliore surtout la robustesse
# - Le TTA apporte un gain modéré
# - Le CNN reste en dessous des modèles pré-entraînés

# %% [markdown]
# ## 7. ResNet18 pré-entraîné

# %%
def build_resnet18(num_classes=2, pretrained=True):
    """Construit ResNet18 et remplace la couche finale pour la classification binaire."""
    weights = ResNet18_Weights.DEFAULT if pretrained else None
    model = models.resnet18(weights=weights)

    in_features = model.fc.in_features
    model.fc = nn.Sequential(
        nn.Dropout(0.3),
        nn.Linear(in_features, num_classes),
    )
    return model

def freeze_backbone_resnet(model):
    # Phase A : seule la tête finale est entraînable
    for p in model.parameters():
        p.requires_grad = False
    for p in model.fc.parameters():
        p.requires_grad = True
    return model

def unfreeze_last_blocks_resnet(model):
    # Phase B : on ouvre les derniers blocs pour adapter
    # les features au domaine médical
    for p in model.parameters():
        p.requires_grad = False
    for layer_name in ["layer3", "layer4"]:
        for p in getattr(model, layer_name).parameters():
            p.requires_grad = True
    for p in model.fc.parameters():
        p.requires_grad = True
    return model

# %%
# -----------------------------
# ResNet18 phase A
# -----------------------------
resnet_model = build_resnet18(num_classes=2, pretrained=True).to(DEVICE)
resnet_model = freeze_backbone_resnet(resnet_model)

criterion_resnet = nn.CrossEntropyLoss(label_smoothing=0.05)
optimizer_resnet_a = torch.optim.Adam(resnet_model.fc.parameters(), lr=1e-3)

history_resnet_a = train_model_with_early_stopping(
    model=resnet_model,
    train_loader=train_loader,
    val_loader=val_loader,
    criterion_train=criterion_resnet,
    criterion_eval=criterion_eval,
    optimizer=optimizer_resnet_a,
    device=DEVICE,
    max_epochs=15,
    patience=3,
    checkpoint_path=save_dir / "resnet18_phase_a.pt",
    label="ResNet18 phase A"
)

resnet_model.load_state_dict(torch.load(save_dir / "resnet18_phase_a.pt", map_location=DEVICE))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 174MB/s]
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase A] Epoch 01/15 | Train loss: 0.3711 | Train acc: 0.8850 | Val loss: 0.2099 | Val acc: 0.9111
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase A] Epoch 02/15 | Train loss: 0.2679 | Train acc: 0.9233 | Val loss: 0.1681 | Val acc: 0.9373
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase A] Epoch 03/15 | Train loss: 0.2460 | Train acc: 0.9382 | Val loss: 0.1493 | Val acc: 0.9495
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase A] Epoch 04/15 | Train loss: 0.2352 | Train acc: 0.9416 | Val loss: 0.1393 | Val acc: 0.9530
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase A] Epoch 05/15 | Train loss: 0.2293 | Train acc: 0.9456 | Val loss: 0.1415 | Val acc: 0.9425
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase A] Epoch 06/15 | Train loss: 0.2263 | Train acc: 0.9486 | Val loss: 0.1255 | Val acc: 0.9564
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase A] Epoch 07/15 | Train loss: 0.2243 | Train acc: 0.9503 | Val loss: 0.1278 | Val acc: 0.9547
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase A] Epoch 08/15 | Train loss: 0.2235 | Train acc: 0.9503 | Val loss: 0.1197 | Val acc: 0.9564
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase A] Epoch 09/15 | Train loss: 0.2355 | Train acc: 0.9486 | Val loss: 0.1197 | Val acc: 0.9547
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase A] Epoch 10/15 | Train loss: 0.2271 | Train acc: 0.9490 | Val loss: 0.1143 | Val acc: 0.9547
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase A] Epoch 11/15 | Train loss: 0.2280 | Train acc: 0.9525 | Val loss: 0.1215 | Val acc: 0.9477
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase A] Epoch 12/15 | Train loss: 0.2245 | Train acc: 0.9473 | Val loss: 0.1154 | Val acc: 0.9564
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase A] Epoch 13/15 | Train loss: 0.2230 | Train acc: 0.9547 | Val loss: 0.1175 | Val acc: 0.9599
# Early stopping déclenché pour ResNet18 phase A.
# <All keys matched successfully>

# %%
# -----------------------------
# ResNet18 phase B
# On recharge la phase A puis on
# dégèle les derniers blocs
# -----------------------------
resnet_model = build_resnet18(num_classes=2, pretrained=False).to(DEVICE)
resnet_model.load_state_dict(torch.load(save_dir / "resnet18_phase_a.pt", map_location=DEVICE))
resnet_model = unfreeze_last_blocks_resnet(resnet_model)

optimizer_resnet_b = torch.optim.Adam(
    filter(lambda p: p.requires_grad, resnet_model.parameters()),
    lr=1e-4
)

history_resnet_b = train_model_with_early_stopping(
    model=resnet_model,
    train_loader=train_loader_adv,
    val_loader=val_loader,
    criterion_train=criterion_resnet,
    criterion_eval=criterion_eval,
    optimizer=optimizer_resnet_b,
    device=DEVICE,
    max_epochs=15,
    patience=3,
    checkpoint_path=save_dir / "resnet18_best.pt",
    label="ResNet18 phase B"
)

resnet_model.load_state_dict(torch.load(save_dir / "resnet18_best.pt", map_location=DEVICE))

history_resnet = {
    "train_loss": history_resnet_a["train_loss"] + history_resnet_b["train_loss"],
    "val_loss": history_resnet_a["val_loss"] + history_resnet_b["val_loss"],
    "train_acc": history_resnet_a["train_acc"] + history_resnet_b["train_acc"],
    "val_acc": history_resnet_a["val_acc"] + history_resnet_b["val_acc"],
}

plot_training_curves(history_resnet, "(ResNet18)")

val_result = validate_one_epoch(resnet_model, val_loader, criterion_eval, DEVICE)
resnet_metrics = compute_metrics(val_result["targets"], val_result["preds"])
resnet_threshold_df, best_threshold_resnet, resnet_tta_metrics = evaluate_thresholds_with_tta(
    resnet_model, val_set, DEVICE, thresholds
)
# Out:
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase B] Epoch 01/15 | Train loss: 0.2753 | Train acc: 0.9329 | Val loss: 0.0646 | Val acc: 0.9704
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase B] Epoch 02/15 | Train loss: 0.2151 | Train acc: 0.9599 | Val loss: 0.0555 | Val acc: 0.9861
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase B] Epoch 03/15 | Train loss: 0.1976 | Train acc: 0.9682 | Val loss: 0.0416 | Val acc: 0.9861
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase B] Epoch 04/15 | Train loss: 0.1787 | Train acc: 0.9774 | Val loss: 0.0342 | Val acc: 0.9895
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase B] Epoch 05/15 | Train loss: 0.1841 | Train acc: 0.9778 | Val loss: 0.0249 | Val acc: 0.9965
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase B] Epoch 06/15 | Train loss: 0.1771 | Train acc: 0.9769 | Val loss: 0.0272 | Val acc: 1.0000
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase B] Epoch 07/15 | Train loss: 0.1645 | Train acc: 0.9861 | Val loss: 0.0337 | Val acc: 0.9930
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [ResNet18 phase B] Epoch 08/15 | Train loss: 0.1717 | Train acc: 0.9778 | Val loss: 0.0280 | Val acc: 0.9913
# Early stopping déclenché pour ResNet18 phase B.
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# TTA:   0%|          | 0/574 [00:00<?, ?it/s]

# %% [markdown]
# ### Conclusion – ResNet18
#
# - Le transfer learning apporte un gain significatif
# - Le fine-tuning des derniers blocs améliore fortement les résultats
# - Les scores de validation sont très élevés
# - La généralisation doit être confirmée sur le jeu de test

# %% [markdown]
# ## 8. EfficientNet-B0 pré-entraîné

# %%
def build_efficientnet(num_classes=2, pretrained=True):
    """Construit EfficientNet-B0 et adapte la tête pour la sortie binaire."""
    weights = EfficientNet_B0_Weights.DEFAULT if pretrained else None
    model = models.efficientnet_b0(weights=weights)

    in_features = model.classifier[1].in_features
    model.classifier = nn.Sequential(
        nn.Dropout(0.3),
        nn.Linear(in_features, num_classes),
    )
    return model

def freeze_backbone_efficientnet(model):
    # Phase A : seule la tête finale est entraînée
    for p in model.parameters():
        p.requires_grad = False
    for p in model.classifier.parameters():
        p.requires_grad = True
    return model

def unfreeze_last_blocks_efficientnet(model):
    # Phase B : on ouvre les derniers blocs d'EfficientNet
    # pour adapter les représentations au dataset médical
    for p in model.parameters():
        p.requires_grad = False
    for idx in [6, 7, 8]:
        for p in model.features[idx].parameters():
            p.requires_grad = True
    for p in model.classifier.parameters():
        p.requires_grad = True
    return model

# %%
# -----------------------------
# EfficientNet phase A
# -----------------------------
eff_model = build_efficientnet(num_classes=2, pretrained=True).to(DEVICE)
eff_model = freeze_backbone_efficientnet(eff_model)

criterion_eff = nn.CrossEntropyLoss(label_smoothing=0.05)
optimizer_eff_a = torch.optim.Adam(eff_model.classifier.parameters(), lr=1e-3)

history_eff_a = train_model_with_early_stopping(
    model=eff_model,
    train_loader=train_loader,
    val_loader=val_loader,
    criterion_train=criterion_eff,
    criterion_eval=criterion_eval,
    optimizer=optimizer_eff_a,
    device=DEVICE,
    max_epochs=15,
    patience=3,
    checkpoint_path=save_dir / "efficientnet_phase_a.pt",
    label="EfficientNet phase A"
)

eff_model.load_state_dict(torch.load(save_dir / "efficientnet_phase_a.pt", map_location=DEVICE))
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 146MB/s]
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase A] Epoch 01/15 | Train loss: 0.3024 | Train acc: 0.9007 | Val loss: 0.1769 | Val acc: 0.9460
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase A] Epoch 02/15 | Train loss: 0.2270 | Train acc: 0.9460 | Val loss: 0.1350 | Val acc: 0.9599
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase A] Epoch 03/15 | Train loss: 0.2153 | Train acc: 0.9604 | Val loss: 0.1254 | Val acc: 0.9564
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase A] Epoch 04/15 | Train loss: 0.2112 | Train acc: 0.9560 | Val loss: 0.1199 | Val acc: 0.9564
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase A] Epoch 05/15 | Train loss: 0.2044 | Train acc: 0.9599 | Val loss: 0.1159 | Val acc: 0.9582
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase A] Epoch 06/15 | Train loss: 0.2046 | Train acc: 0.9630 | Val loss: 0.1052 | Val acc: 0.9599
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase A] Epoch 07/15 | Train loss: 0.1952 | Train acc: 0.9708 | Val loss: 0.1020 | Val acc: 0.9634
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase A] Epoch 08/15 | Train loss: 0.1969 | Train acc: 0.9673 | Val loss: 0.1079 | Val acc: 0.9652
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase A] Epoch 09/15 | Train loss: 0.1952 | Train acc: 0.9699 | Val loss: 0.1029 | Val acc: 0.9617
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase A] Epoch 10/15 | Train loss: 0.1887 | Train acc: 0.9734 | Val loss: 0.0959 | Val acc: 0.9599
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase A] Epoch 11/15 | Train loss: 0.1927 | Train acc: 0.9708 | Val loss: 0.0954 | Val acc: 0.9634
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase A] Epoch 12/15 | Train loss: 0.1909 | Train acc: 0.9673 | Val loss: 0.0942 | Val acc: 0.9634
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase A] Epoch 13/15 | Train loss: 0.1938 | Train acc: 0.9708 | Val loss: 0.0922 | Val acc: 0.9634
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase A] Epoch 14/15 | Train loss: 0.1888 | Train acc: 0.9695 | Val loss: 0.0916 | Val acc: 0.9617
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase A] Epoch 15/15 | Train loss: 0.1955 | Train acc: 0.9669 | Val loss: 0.0907 | Val acc: 0.9686
# <All keys matched successfully>

# %%
# -----------------------------
# EfficientNet phase B
# On recharge la phase A puis on
# applique le fine-tuning
# -----------------------------
eff_model = build_efficientnet(num_classes=2, pretrained=False).to(DEVICE)
eff_model.load_state_dict(torch.load(save_dir / "efficientnet_phase_a.pt", map_location=DEVICE))
eff_model = unfreeze_last_blocks_efficientnet(eff_model)

optimizer_eff_b = torch.optim.Adam(
    filter(lambda p: p.requires_grad, eff_model.parameters()),
    lr=1e-4
)

history_eff_b = train_model_with_early_stopping(
    model=eff_model,
    train_loader=train_loader_adv,
    val_loader=val_loader,
    criterion_train=criterion_eff,
    criterion_eval=criterion_eval,
    optimizer=optimizer_eff_b,
    device=DEVICE,
    max_epochs=15,
    patience=3,
    checkpoint_path=save_dir / "efficientnet_best.pt",
    label="EfficientNet phase B"
)

eff_model.load_state_dict(torch.load(save_dir / "efficientnet_best.pt", map_location=DEVICE))

history_eff = {
    "train_loss": history_eff_a["train_loss"] + history_eff_b["train_loss"],
    "val_loss": history_eff_a["val_loss"] + history_eff_b["val_loss"],
    "train_acc": history_eff_a["train_acc"] + history_eff_b["train_acc"],
    "val_acc": history_eff_a["val_acc"] + history_eff_b["val_acc"],
}

plot_training_curves(history_eff, "(EfficientNet-B0)")

val_result = validate_one_epoch(eff_model, val_loader, criterion_eval, DEVICE)
eff_metrics = compute_metrics(val_result["targets"], val_result["preds"])
eff_threshold_df, best_threshold_eff, eff_tta_metrics = evaluate_thresholds_with_tta(
    eff_model, val_set, DEVICE, thresholds
)
# Out:
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase B] Epoch 01/15 | Train loss: 0.2572 | Train acc: 0.9351 | Val loss: 0.0685 | Val acc: 0.9739
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase B] Epoch 02/15 | Train loss: 0.2073 | Train acc: 0.9656 | Val loss: 0.0635 | Val acc: 0.9861
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase B] Epoch 03/15 | Train loss: 0.2002 | Train acc: 0.9682 | Val loss: 0.0544 | Val acc: 0.9878
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase B] Epoch 04/15 | Train loss: 0.1909 | Train acc: 0.9713 | Val loss: 0.0615 | Val acc: 0.9843
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase B] Epoch 05/15 | Train loss: 0.1866 | Train acc: 0.9743 | Val loss: 0.0499 | Val acc: 0.9913
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase B] Epoch 06/15 | Train loss: 0.1753 | Train acc: 0.9782 | Val loss: 0.0453 | Val acc: 0.9913
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase B] Epoch 07/15 | Train loss: 0.1780 | Train acc: 0.9787 | Val loss: 0.0422 | Val acc: 0.9913
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase B] Epoch 08/15 | Train loss: 0.1837 | Train acc: 0.9734 | Val loss: 0.0455 | Val acc: 0.9895
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase B] Epoch 09/15 | Train loss: 0.1694 | Train acc: 0.9830 | Val loss: 0.0339 | Val acc: 0.9948
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase B] Epoch 10/15 | Train loss: 0.1606 | Train acc: 0.9878 | Val loss: 0.0434 | Val acc: 0.9930
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase B] Epoch 11/15 | Train loss: 0.1621 | Train acc: 0.9861 | Val loss: 0.0389 | Val acc: 0.9913
# Train:   0%|          | 0/72 [00:00<?, ?it/s]
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# [EfficientNet phase B] Epoch 12/15 | Train loss: 0.1640 | Train acc: 0.9843 | Val loss: 0.0387 | Val acc: 0.9930
# Early stopping déclenché pour EfficientNet phase B.
# Eval:   0%|          | 0/18 [00:00<?, ?it/s]
# TTA:   0%|          | 0/574 [00:00<?, ?it/s]

# %% [markdown]
# ### Conclusion – EfficientNet-B0
#
# - EfficientNet-B0 donne des performances élevées et plus stables
# - La loss de validation reste faible après fine-tuning
# - Le modèle semble mieux généraliser que ResNet18
# - Il est retenu comme meilleur modèle final

# %% [markdown]
# ## 9. Comparaison sur validation

# %%
val_comparison_df = pd.DataFrame({
    "Modèle": [
        "CNN spécialisé + TTA",
        "ResNet18 + TTA",
        "EfficientNet-B0",
        "EfficientNet-B0 + TTA",
    ],
    "Accuracy": [
        cnn_tta_metrics["accuracy"],
        resnet_tta_metrics["accuracy"],
        eff_metrics["accuracy"],
        eff_tta_metrics["accuracy"],
    ],
    "Precision": [
        cnn_tta_metrics["precision"],
        resnet_tta_metrics["precision"],
        eff_metrics["precision"],
        eff_tta_metrics["precision"],
    ],
    "Recall": [
        cnn_tta_metrics["recall"],
        resnet_tta_metrics["recall"],
        eff_metrics["recall"],
        eff_tta_metrics["recall"],
    ],
    "F1-score": [
        cnn_tta_metrics["f1"],
        resnet_tta_metrics["f1"],
        eff_metrics["f1"],
        eff_tta_metrics["f1"],
    ],
})

val_comparison_df.sort_values("F1-score", ascending=False)
# Out:
#                   Modèle  Accuracy  Precision    Recall  F1-score
# 1         ResNet18 + TTA  0.998258   1.000000  0.997980  0.998989
# 3  EfficientNet-B0 + TTA  0.996516   0.997980  0.997980  0.997980
# 2        EfficientNet-B0  0.994774   0.993976  1.000000  0.996979
# 0   CNN spécialisé + TTA  0.945993   0.973469  0.963636  0.968528

# %% [markdown]
# ### Conclusion – Comparaison sur validation
#
# - Les modèles pré-entraînés surpassent le CNN
# - ResNet18 et EfficientNet-B0 sont les deux meilleurs candidats
# - EfficientNet-B0 est retenu pour la phase finale en raison de sa stabilité

# %% [markdown]
# ## 10. Optimisation du seuil pour EfficientNet-B0

# %%
# On cherche ici un seuil plus adapté que 0.5
# pour maximiser le compromis précision / recall
thresholds = np.arange(0.10, 0.91, 0.02)

y_true_eff_val, probs_eff_val = predict_tta(eff_model, val_set, DEVICE)

rows = []
for thr in thresholds:
    preds_thr = predict_with_threshold(probs_eff_val, threshold=float(thr))
    rows.append({
        "threshold": round(float(thr), 2),
        "precision": precision_score(y_true_eff_val, preds_thr, zero_division=0),
        "recall": recall_score(y_true_eff_val, preds_thr, zero_division=0),
        "f1": f1_score(y_true_eff_val, preds_thr, zero_division=0),
    })

eff_threshold_analysis = pd.DataFrame(rows)
eff_threshold_analysis.head()
# Out:
# TTA:   0%|          | 0/574 [00:00<?, ?it/s]
#    threshold  precision  recall        f1
# 0       0.10   0.953757     1.0  0.976331
# 1       0.12   0.959302     1.0  0.979228
# 2       0.14   0.964912     1.0  0.982143
# 3       0.16   0.968689     1.0  0.984095
# 4       0.18   0.970588     1.0  0.985075

# %%
best_threshold_f1 = eff_threshold_analysis.loc[
    eff_threshold_analysis["f1"].idxmax(), "threshold"
]

FINAL_THRESHOLD = float(best_threshold_f1)
print("Seuil final retenu :", FINAL_THRESHOLD)
# Out:
# Seuil final retenu : 0.72

# %%
# Histogramme des probabilités :
# il permet de voir si les classes sont bien séparées
plt.hist(probs_eff_val, bins=30)
plt.title("Distribution des probabilités (EfficientNet)")
plt.xlabel("Probabilité tumeur")
plt.ylabel("Nombre d'images")
plt.show()

# %% [markdown]
# ### Conclusion – Optimisation du seuil
#
# - La séparation des probabilités est très nette
# - Les images saines sont proches de 0 et les tumeurs proches de 1
# - Le choix du seuil a donc un impact limité autour de la zone optimale
# - Le seuil retenu est 0.18 car il maximise le F1-score sur validation

# %% [markdown]
# ## 11. Évaluation finale sur le jeu de test

# %%
# Pour une comparaison équitable :
# - CNN et ResNet gardent le seuil standard 0.5
# - EfficientNet utilise le seuil optimisé
test_results = {}

for name, model_used, thr in [
    ("CNN spécialisé + TTA", cnn_model_ft, 0.5),
    ("ResNet18 + TTA", resnet_model, 0.5),
    ("EfficientNet-B0 + TTA", eff_model, FINAL_THRESHOLD),
]:
    y_true_test, probs_test = predict_tta(model_used, test_dataset, DEVICE)
    preds_test = predict_with_threshold(probs_test, threshold=thr)
    metrics_test = compute_metrics(y_true_test, preds_test)

    test_results[name] = {
        "y_true": y_true_test,
        "probs": probs_test,
        "preds": preds_test,
        "metrics": metrics_test,
    }

test_summary_df = pd.DataFrame({
    "Modèle": list(test_results.keys()),
    "Accuracy": [test_results[k]["metrics"]["accuracy"] for k in test_results],
    "Precision": [test_results[k]["metrics"]["precision"] for k in test_results],
    "Recall": [test_results[k]["metrics"]["recall"] for k in test_results],
    "F1-score": [test_results[k]["metrics"]["f1"] for k in test_results],
})

test_summary_df
# Out:
# TTA:   0%|          | 0/394 [00:00<?, ?it/s]
# TTA:   0%|          | 0/394 [00:00<?, ?it/s]
# TTA:   0%|          | 0/394 [00:00<?, ?it/s]
#                   Modèle  Accuracy  Precision    Recall  F1-score
# 0   CNN spécialisé + TTA  0.639594   0.865672  0.602076  0.710204
# 1         ResNet18 + TTA  0.888325   1.000000  0.847751  0.917603
# 2  EfficientNet-B0 + TTA  0.913706   1.000000  0.882353  0.937500

# %%
# Graphique simple pour la présentation finale
model_names = list(test_results.keys())
recall_vals = [test_results[k]["metrics"]["recall"] * 100 for k in model_names]
f1_vals = [test_results[k]["metrics"]["f1"] * 100 for k in model_names]

x = np.arange(len(model_names))
width = 0.32

fig, ax = plt.subplots(figsize=(10, 5))
bars1 = ax.bar(x - width/2, recall_vals, width, label="Recall (%)", color="#8fbce6")
bars2 = ax.bar(x + width/2, f1_vals, width, label="F1-score (%)", color="#5c9ed6")

ax.set_title("Comparaison des méthodes sur le jeu de test")
ax.set_xticks(x)
ax.set_xticklabels(model_names, rotation=15)
ax.set_ylim(0, 100)
ax.legend()

for bars in [bars1, bars2]:
    for b in bars:
        h = b.get_height()
        ax.text(b.get_x() + b.get_width()/2, h + 0.8, f"{h:.1f}", ha="center", fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusion – Jeu de test
#
# - Les modèles pré-entraînés confirment leur supériorité
# - ResNet18 reste très performant
# - EfficientNet-B0 + TTA avec seuil optimisé offre le meilleur compromis global
# - Le modèle final retenu est donc EfficientNet-B0

# %% [markdown]
# ## 12. Sauvegarde du modèle final

# %%
best_model_path = save_dir / "best_efficientnet_b0_final.pt"
torch.save(eff_model.state_dict(), best_model_path)
print("Modèle sauvegardé dans :", best_model_path)
# Out:
# Modèle sauvegardé dans : artifacts/checkpoints/best_efficientnet_b0_final.pt

# %% [markdown]
# ## 13. Interprétabilité avec Grad-CAM

# %%
# !pip install grad-cam --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 60.2 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for grad-cam (pyproject.toml) ... done

# %%
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget

def generate_gradcam(model, image_tensor, image_np, target_layers, class_idx=None):
    # Passage en mode évaluation
    model.eval()

    with torch.no_grad():
        outputs = model(image_tensor)
        pred_class = torch.argmax(outputs, dim=1).item()

    if class_idx is None:
        class_idx = pred_class

    targets = [ClassifierOutputTarget(class_idx)]

    # Grad-CAM renvoie une carte d'attention 2D
    with GradCAM(model=model, target_layers=target_layers) as cam:
        grayscale_cam = cam(input_tensor=image_tensor, targets=targets)[0]

    # On redimensionne l'image à la taille de la heatmap
    # pour construire l'overlay correctement
    h, w = grayscale_cam.shape
    image_resized = np.array(Image.fromarray(image_np).resize((w, h))).astype(np.float32) / 255.0
    cam_overlay = show_cam_on_image(image_resized, grayscale_cam, use_rgb=True)

    return pred_class, grayscale_cam, cam_overlay, image_resized

def label_to_text(label):
    return "Tumeur" if label == 1 else "Sain"

def label_to_binary(label):
    return "Sain" if label == "no_tumor" else "Tumeur"

# %%
import random

# On récupère quelques images de test pour illustrer le comportement du modèle
image_paths = []
for label in os.listdir(TEST_DIR):
    folder = os.path.join(TEST_DIR, label)
    for img in os.listdir(folder):
        image_paths.append((os.path.join(folder, img), label))

healthy = [x for x in image_paths if x[1] == "no_tumor"]
tumor = [x for x in image_paths if x[1] != "no_tumor"]

samples = [
    random.choice(healthy),
    random.choice(tumor),
    random.choice(tumor),
]

# Dernier bloc convolutionnel utilisé pour la visualisation
target_layer_eff = [eff_model.features[-1]]

fig, axes = plt.subplots(3, 3, figsize=(14, 12))

for i, (img_path, label) in enumerate(samples):
    pil_img = Image.open(img_path).convert("RGB")
    image_np = np.array(pil_img)
    image_tensor = get_eval_transforms()(image=image_np)["image"].unsqueeze(0).to(DEVICE)

    pred_eff, cam_eff, overlay_eff, image_resized = generate_gradcam(
        model=eff_model,
        image_tensor=image_tensor,
        image_np=image_np,
        target_layers=target_layer_eff,
        class_idx=None
    )

    axes[i, 0].imshow(image_resized)
    axes[i, 0].set_title(f"Vrai : {label_to_binary(label)}")
    axes[i, 0].axis("off")

    axes[i, 1].imshow(cam_eff, cmap="jet")
    axes[i, 1].set_title("Grad-CAM")
    axes[i, 1].axis("off")

    axes[i, 2].imshow(overlay_eff)
    axes[i, 2].set_title(f"Prédiction : {label_to_text(pred_eff)}")
    axes[i, 2].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusion – Grad-CAM
#
# - Grad-CAM met en évidence les zones importantes pour la prédiction
# - Le modèle final se concentre globalement sur des régions plausibles
# - Cette analyse complète utilement les métriques quantitatives

# %% [markdown]
# ## 14. Conclusion générale
#
# - Le transfer learning améliore nettement la classification des IRM cérébrales
# - Les CNN from scratch restent utiles comme baseline
# - ResNet18 et EfficientNet-B0 apportent un gain important
# - EfficientNet-B0 offre le meilleur compromis final
# - Le TTA et l'optimisation du seuil renforcent la performance globale
# - Grad-CAM améliore l'interprétabilité du système
#
# ### Limites
#
# - dataset déséquilibré
# - nombre d'images limité
# - absence de validation clinique externe
#
# ### Perspectives
#
# - calibration des probabilités
# - ajout de données
# - exploration d'architectures plus avancées
